# %% [markdown]
# <a href="https://colab.research.google.com/github/shubhamrai1318/Resume_Ranking_System/blob/main/ResumeRankingSystem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Resume Ranking System

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import re
from nltk.corpus import wordnet
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords as stp
from sklearn.feature_extraction.text import CountVectorizer
# nltk.download()

# %% [markdown]
# ## Loading Dataset

# %%
# Mounting the Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/Shubham/CsvFiles/Resume Ranking Data Set.csv')
df
# Out:
#                                 accomplishments_segment  \
# 0                                                   NaN
# 1                                                   NaN
# 2     Successfully cleared and completed the course ...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1568                                                NaN
# 1569                                                NaN
# 1570                                                NaN
# 1571                                                NaN
# 1572                                                NaN
#
#                           degree  \
# 0              MS , B.TECH , PhD
# 1              B.E , MS , M.TECH
# 2               MS , B.TECH , BS
# 3                  B.E , MS , BS
# 4               MS , B.TECH , BS
# ...                          ...
# 1568           B.E , MS , M.TECH
# 1569                     MS , BS
# 1570  B.S , M.Sc , M.S , BS , MS
# 1571                          MS
# 1572                          BS
#
#                                       education_segment  \
# 0                                                   NaN
# 1     M.Tech. Data Science\nJSS Science And Technolo...
# 2     Degree\nInstitute\nBoard/University\nYear\nPer...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1568  M.Tech (2019-2021) \n Digital Communication\nO...
# 1569                                                NaN
# 1570                                                NaN
# 1571                                                NaN
# 1572                                                NaN
#
#                             emails  \
# 0       sutarvinayak2063@gmail.com
# 1                pooj.vs@gmail.com
# 2     khandelwal.ashwin5@gmail.com
# 3                              NaN
# 4                              NaN
# ...                            ...
# 1568     gauravarora0320@gmail.com
# 1569          hey@ayokunlepaul.dev
# 1570                           NaN
# 1571      j.udaysaikiran@gmail.com
# 1572     shindeyashshree@gmail.com
#
#                                              job_titles  \
# 0                        full stack developer , student
# 1                                     software engineer
# 2                                                   NaN
# 3     work from home , support analyst , software an...
# 4                           work from home , classifier
# ...                                                 ...
# 1568  branch manager , embedded software developer ,...
# 1569      devops , senior android developer , team lead
# 1570  devops engineer , traffic manager , release ma...
# 1571                                         classifier
# 1572                                                NaN
#
#                                                   links  \
# 0     https://github.com/ramsuthar305/SIH2019 , http...
# 1                                               pooj.vs
# 2     https://www.linkedin.com/in/ashwin-khandelwal-...
# 3                                                   NaN
# 4     https://github.com/ajay1013/Titanic-ML-from-Di...
# ...                                                 ...
# 1568  https://www.linkedin.com/in , https://grv20.gi...
# 1569  com.gokada , https://play.google.com/store/app...
# 1570  https://freesearch.naukri.com/preview/printResume
# 1571                                                NaN
# 1572                 https://github.com/YashshreeShinde
#
#                                            misc_segment                  name  \
# 0                                                   NaN          Prasad Nagar
# 1     06/2017 – 07/2019\n07/2018 – 07/2019\nmailto:p...     Software Engineer
# 2                                                   NaN     Ashwin Khandelwal
# 3                                                   NaN  Computer Engineering
# 4                                                   NaN             Python
# ...                                                 ...                   ...
# 1568                                                NaN          Gaurav Arora
# 1569                                                NaN         Ayokunle Paul
# 1570                                                NaN       DevOps Engineer
# 1571                                                NaN        Udaya SaiKiran
# 1572                                                NaN             D. Shinde
#
#                                      objectives_segment          phone  ...  \
# 0                                                   NaN  +919309161108  ...
# 1                                                   NaN     7411786822  ...
# 2     I seek challenging environment to work in, tha...     9462710290  ...
# 3                                                   NaN   919930485336  ...
# 4                                                   NaN   918010295832  ...
# ...                                                 ...            ...  ...
# 1568                                                NaN  +919644527421  ...
# 1569                                                NaN     9035350600  ...
# 1570                                                NaN    17051313590  ...
# 1571                                                NaN  +917569799250  ...
# 1572                                                NaN     9762552867  ...
#
#                                                    text  \
# 0     VINAYAK \nSUTAR \nLinkedIn  \n+91 9309161108  ...
# 1     POOJA V S\nSoftware Engineer\nRich exposure to...
# 2     Ashwin Khandelwal          \n Email id – khand...
# 3     Assessment\nQ1. Why should you be hired for th...
# 4     Assessment\nQ1. Why should you be hired for th...
# ...                                                 ...
# 1568  Gaurav Arora\nFull Stack Developer\ngauravaror...
# 1569  Ayokunle Paul\nLagos, Nigeria · hey@ayokunlepa...
# 1570  10/02/2021 https://freesearch.naukri.com/previ...
# 1571  Udaya SaiKiran.Jonnakuti \n +91-7569799250    ...
# 1572  Yashshree  D. Shinde \nC/104, Manas Sarovar Bl...
#
#                                            university_0  \
# 0                     national, mainpuri, uttar pradesh
# 1                         government, kandhamal, odisha
# 2     narsee monjee institute of management studies,...
# 3                              master, medak, telangana
# 4     greater noida institute of technology, gautam ...
# ...                                                 ...
# 1568                                                NaN
# 1569                                                NaN
# 1570                                                NaN
# 1571              engineering college, ajmer, rajasthan
# 1572                                                NaN
#
#                                            university_1  \
# 0                   college of arts, sundargarh, odisha
# 1     vidya vardhaka college of engineering, mysore,...
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1568                                                NaN
# 1569                                                NaN
# 1570                                                NaN
# 1571                           master, medak, telangana
# 1572                                                NaN
#
#                                   university_2  \
# 0     school of engineering, ernakulam, kerala
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 1568                                       NaN
# 1569                                       NaN
# 1570                                       NaN
# 1571            r.k., shrawasti, uttar pradesh
# 1572                                       NaN
#
#                          university_3  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ...                               ...
# 1568                              NaN
# 1569                              NaN
# 1570                              NaN
# 1571  s.r.k, firozabad, uttar pradesh
# 1572                              NaN
#
#                                        university_4 university_5  \
# 0                                               NaN          NaN
# 1                                               NaN          NaN
# 2                                               NaN          NaN
# 3                                               NaN          NaN
# 4                                               NaN          NaN
# ...                                             ...          ...
# 1568                                            NaN          NaN
# 1569                                            NaN          NaN
# 1570                                            NaN          NaN
# 1571  harshini degree college, hyderabad, telangana          NaN
# 1572                                            NaN          NaN
#
#                                                     url work_experience  \
# 0     https://training-resumes.s3.ap-south-1.amazona...             NaN
# 1     https://training-resumes.s3.ap-south-1.amazona...             NaN
# 2     https://training-resumes.s3.ap-south-1.amazona...             NaN
# 3     https://training-resumes.s3.ap-south-1.amazona...             1.0
# 4     https://training-resumes.s3.ap-south-1.amazona...             NaN
# ...                                                 ...             ...
# 1568  https://training-resumes.s3.ap-south-1.amazona...             2.0
# 1569  https://training-resumes.s3.ap-south-1.amazona...             2.0
# 1570  https://training-resumes.s3.ap-south-1.amazona...            12.0
# 1571  https://training-resumes.s3.ap-south-1.amazona...             NaN
# 1572  https://training-resumes.s3.ap-south-1.amazona...             NaN
#
#                                            work_segment
# 0                                                   NaN
# 1     Merchandising System' using PL/SQL.\nmaintain ...
# 2     Organization / Institute\nDescription\nBharat ...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1568     \nApril 2020 – Present | Remote          \n...
# 1569  Softcom Lagos, Nigeria\nSenior Android Develop...
# 1570                                                NaN
# 1571                                                NaN
# 1572                                                NaN
#
# [1573 rows x 23 columns]

# %% [markdown]
# ## Handling Null Values

# %%
df.isnull().sum()
# Out:
# accomplishments_segment    1507
# degree                       38
# education_segment          1116
# emails                     1509
# job_titles                   27
# links                       354
# misc_segment               1551
# name                          1
# objectives_segment         1159
# phone                       219
# projects_segment            893
# skills                        0
# skills_segment             1105
# text                          0
# university_0               1007
# university_1               1305
# university_2               1480
# university_3               1545
# university_4               1568
# university_5               1571
# url                           0
# work_experience             854
# work_segment                893
# dtype: int64

# %% [markdown]
# ## Dropping Unuseful Features

# %%
df.drop(['accomplishments_segment','education_segment','emails','misc_segment','name','objectives_segment','phone','projects_segment','skills_segment','text',
         'university_0','university_1','university_2','university_3','university_4','university_5','url','work_segment'],axis=1,inplace=True)
df
# Out:
#                           degree  \
# 0              MS , B.TECH , PhD
# 1              B.E , MS , M.TECH
# 2               MS , B.TECH , BS
# 3                  B.E , MS , BS
# 4               MS , B.TECH , BS
# ...                          ...
# 1568           B.E , MS , M.TECH
# 1569                     MS , BS
# 1570  B.S , M.Sc , M.S , BS , MS
# 1571                          MS
# 1572                          BS
#
#                                              job_titles  \
# 0                        full stack developer , student
# 1                                     software engineer
# 2                                                   NaN
# 3     work from home , support analyst , software an...
# 4                           work from home , classifier
# ...                                                 ...
# 1568  branch manager , embedded software developer ,...
# 1569      devops , senior android developer , team lead
# 1570  devops engineer , traffic manager , release ma...
# 1571                                         classifier
# 1572                                                NaN
#
#                                                   links  \
# 0     https://github.com/ramsuthar305/SIH2019 , http...
# 1                                               pooj.vs
# 2     https://www.linkedin.com/in/ashwin-khandelwal-...
# 3                                                   NaN
# 4     https://github.com/ajay1013/Titanic-ML-from-Di...
# ...                                                 ...
# 1568  https://www.linkedin.com/in , https://grv20.gi...
# 1569  com.gokada , https://play.google.com/store/app...
# 1570  https://freesearch.naukri.com/preview/printResume
# 1571                                                NaN
# 1572                 https://github.com/YashshreeShinde
#
#                                                  skills  work_experience
# 0     algorithms , interview , visualisation , robot...              NaN
# 1     core java , algorithms , sql tools , deep lear...              NaN
# 2     digital signal processing , algorithms , capac...              NaN
# 3     big data analytics , award , training , comput...              1.0
# 4     functionality , algorithms , spark , data visu...              NaN
# ...                                                 ...              ...
# 1568  digital communication , api , atom , robot , c...              2.0
# 1569  reporting , functionality , socket.io , mockit...              2.0
# 1570  version control , renewals , nfs , telugu , vi...             12.0
# 1571  natural language , matplotlib , boost , custom...              NaN
# 1572  employability , python , github , javascript ,...              NaN
#
# [1573 rows x 5 columns]

# %%
print('After removing the columns from dataset..')
df.isnull().sum()
# Out:
# After removing the columns from dataset..
# degree              38
# job_titles          27
# links              354
# skills               0
# work_experience    854
# dtype: int64

# %%
# Fill missing values in 'degree' with the mode
df['degree'].fillna(df['degree'].mode()[0], inplace=True)

# Fill missing values in 'links' with a placeholder ('Missing')
df['links'].fillna('Missing', inplace=True)

# Fill missing values in 'work_experience' with 0
df['work_experience'].fillna(0, inplace=True)

# Fill missing values in 'job_titles' with a placeholder ('No Job')
df['job_titles'].fillna('No Job', inplace=True)

# %% [markdown]
# ## Data Preprocessing and Transformation

# %%
all_degrees = ''
for i in df.degree:
  if len(all_degrees) == 0:
    all_degrees = i
  else:
    all_degrees = all_degrees + ' , ' + i

all_degrees = all_degrees.split(',')
all_degrees = [re.sub("[\s.]","",i).upper() for i in all_degrees]
unique_degrees = set(all_degrees)
unique_degrees
# Out:
# {'BE', 'BS', 'BSC', 'BTECH', 'ME', 'MS', 'MSC', 'MTECH', 'PHD'}

# %%
df['bachelor_degrees'] = 'No Degree'
df['master_degrees'] = 'No Degree'
df['docterte_degrees'] = 'No Degree'
df['profiles'] = 'No Profile'

# %%
ind = 0
for i in df.degree:
  lst = re.sub("[\s.]","",i).upper( )
  # print(lst)
  for j in lst.split(','):
    if j in ['BE', 'BS', 'BSC', 'BTECH']:
      if df.loc[ind,'bachelor_degrees'] == 'No Degree':
        df.loc[ind,'bachelor_degrees'] = j
      else:
        df.loc[ind,'bachelor_degrees'] = df.loc[ind,'bachelor_degrees'] + ' , '+ j
    elif j in ['ME', 'MS', 'MSC', 'MTECH']:
      if df.loc[ind,'master_degrees'] == 'No Degree':
        df.loc[ind,'master_degrees'] = j
      else:
        df.loc[ind,'master_degrees'] = df.loc[ind,'master_degrees'] + ' , '+ j
    elif j == 'PHD':
      if df.loc[ind,'docterte_degrees'] == 'No Degree':
        df.loc[ind,'docterte_degrees'] = j
      else:
        df.loc[ind,'docterte_degrees'] = df.loc[ind,'docterte_degrees'] + ' , '+ j
  ind +=1

# %%
df
# Out:
#                           degree  \
# 0              MS , B.TECH , PhD
# 1              B.E , MS , M.TECH
# 2               MS , B.TECH , BS
# 3                  B.E , MS , BS
# 4               MS , B.TECH , BS
# ...                          ...
# 1568           B.E , MS , M.TECH
# 1569                     MS , BS
# 1570  B.S , M.Sc , M.S , BS , MS
# 1571                          MS
# 1572                          BS
#
#                                              job_titles  \
# 0                        full stack developer , student
# 1                                     software engineer
# 2                                                No Job
# 3     work from home , support analyst , software an...
# 4                           work from home , classifier
# ...                                                 ...
# 1568  branch manager , embedded software developer ,...
# 1569      devops , senior android developer , team lead
# 1570  devops engineer , traffic manager , release ma...
# 1571                                         classifier
# 1572                                             No Job
#
#                                                   links  \
# 0     https://github.com/ramsuthar305/SIH2019 , http...
# 1                                               pooj.vs
# 2     https://www.linkedin.com/in/ashwin-khandelwal-...
# 3                                               Missing
# 4     https://github.com/ajay1013/Titanic-ML-from-Di...
# ...                                                 ...
# 1568  https://www.linkedin.com/in , https://grv20.gi...
# 1569  com.gokada , https://play.google.com/store/app...
# 1570  https://freesearch.naukri.com/preview/printResume
# 1571                                            Missing
# 1572                 https://github.com/YashshreeShinde
#
#                                                  skills  work_experience  \
# 0     algorithms , interview , visualisation , robot...              0.0
# 1     core java , algorithms , sql tools , deep lear...              0.0
# 2     digital signal processing , algorithms , capac...              0.0
# 3     big data analytics , award , training , comput...              1.0
# 4     functionality , algorithms , spark , data visu...              0.0
# ...                                                 ...              ...
# 1568  digital communication , api , atom , robot , c...              2.0
# 1569  reporting , functionality , socket.io , mockit...              2.0
# 1570  version control , renewals , nfs , telugu , vi...             12.0
# 1571  natural language , matplotlib , boost , custom...              0.0
# 1572  employability , python , github , javascript ,...              0.0
#
#      bachelor_degrees master_degrees docterte_degrees    profiles
# 0               BTECH             MS              PHD  No Profile
# 1                  BE     MS , MTECH        No Degree  No Profile
# 2          BTECH , BS             MS        No Degree  No Profile
# 3             BE , BS             MS        No Degree  No Profile
# 4          BTECH , BS             MS        No Degree  No Profile
# ...               ...            ...              ...         ...
# 1568               BE     MS , MTECH        No Degree  No Profile
# 1569               BS             MS        No Degree  No Profile
# 1570          BS , BS  MSC , MS , MS        No Degree  No Profile
# 1571        No Degree             MS        No Degree  No Profile
# 1572               BS      No Degree        No Degree  No Profile
#
# [1573 rows x 9 columns]

# %%
ind = 0
for i in df.links:
  lst = re.sub("[\s]","",i)
  # print(lst)
  for j in lst.split(','):
    if j.find('github') != -1:
      df.loc[ind,'profiles'] = 'Github'
    elif j.find('linkedin') != -1:
      if df.loc[ind,'profiles'] == 'No Profile':
        df.loc[ind,'profiles'] = 'Linkedin'
      else:
        df.loc[ind,'profiles'] = df.loc[ind,'profiles'] + ' , ' + 'Linkedin'
  ind +=1

# %%
df
# Out:
#                           degree  \
# 0              MS , B.TECH , PhD
# 1              B.E , MS , M.TECH
# 2               MS , B.TECH , BS
# 3                  B.E , MS , BS
# 4               MS , B.TECH , BS
# ...                          ...
# 1568           B.E , MS , M.TECH
# 1569                     MS , BS
# 1570  B.S , M.Sc , M.S , BS , MS
# 1571                          MS
# 1572                          BS
#
#                                              job_titles  \
# 0                        full stack developer , student
# 1                                     software engineer
# 2                                                No Job
# 3     work from home , support analyst , software an...
# 4                           work from home , classifier
# ...                                                 ...
# 1568  branch manager , embedded software developer ,...
# 1569      devops , senior android developer , team lead
# 1570  devops engineer , traffic manager , release ma...
# 1571                                         classifier
# 1572                                             No Job
#
#                                                   links  \
# 0     https://github.com/ramsuthar305/SIH2019 , http...
# 1                                               pooj.vs
# 2     https://www.linkedin.com/in/ashwin-khandelwal-...
# 3                                               Missing
# 4     https://github.com/ajay1013/Titanic-ML-from-Di...
# ...                                                 ...
# 1568  https://www.linkedin.com/in , https://grv20.gi...
# 1569  com.gokada , https://play.google.com/store/app...
# 1570  https://freesearch.naukri.com/preview/printResume
# 1571                                            Missing
# 1572                 https://github.com/YashshreeShinde
#
#                                                  skills  work_experience  \
# 0     algorithms , interview , visualisation , robot...              0.0
# 1     core java , algorithms , sql tools , deep lear...              0.0
# 2     digital signal processing , algorithms , capac...              0.0
# 3     big data analytics , award , training , comput...              1.0
# 4     functionality , algorithms , spark , data visu...              0.0
# ...                                                 ...              ...
# 1568  digital communication , api , atom , robot , c...              2.0
# 1569  reporting , functionality , socket.io , mockit...              2.0
# 1570  version control , renewals , nfs , telugu , vi...             12.0
# 1571  natural language , matplotlib , boost , custom...              0.0
# 1572  employability , python , github , javascript ,...              0.0
#
#      bachelor_degrees master_degrees docterte_degrees           profiles
# 0               BTECH             MS              PHD             Github
# 1                  BE     MS , MTECH        No Degree         No Profile
# 2          BTECH , BS             MS        No Degree           Linkedin
# 3             BE , BS             MS        No Degree         No Profile
# 4          BTECH , BS             MS        No Degree             Github
# ...               ...            ...              ...                ...
# 1568               BE     MS , MTECH        No Degree  Github , Linkedin
# 1569               BS             MS        No Degree         No Profile
# 1570          BS , BS  MSC , MS , MS        No Degree         No Profile
# 1571        No Degree             MS        No Degree         No Profile
# 1572               BS      No Degree        No Degree             Github
#
# [1573 rows x 9 columns]

# %% [markdown]
# ## 3. handling the null values of work_experience and converted it's all data into integer format

# %%
# list(df['work_experience'].unique())
df.work_experience.value_counts()
# Out:
#  0.0       854
#  4.0       151
#  2.0        91
#  1.0        87
#  3.0        81
#  5.0        73
#  6.0        52
#  8.0        34
#  7.0        32
#  9.0        23
#  14.0       14
#  11.0       12
#  10.0       12
#  12.0       11
#  13.0        6
#  18.0        5
#  15.0        4
#  17.0        4
#  21.0        4
#  22.0        2
#  2005.0      2
#  2004.0      2
#  16.0        2
#  2003.0      2
#  2006.0      2
#  20.0        2
#  2002.0      1
#  2010.0      1
#  2001.0      1
#  2012.0      1
# -3.0         1
#  1999.0      1
#  2013.0      1
#  2008.0      1
#  19.0        1
# Name: work_experience, dtype: int64

# %%
ind = 0
for i in df.work_experience:
  if i < 0:
    df.loc[ind,'work_experience'] = i*-1
  elif i > 40:
    df.loc[ind,'work_experience'] = 0
  ind +=1
df['work_experience'] = df['work_experience'].astype(int)

# %% [markdown]
# ## Removing the 'degree' and 'links' from the dataset after feature handling

# %%
df.drop(['degree','links'],axis=1,inplace=True)

# %%
df.isnull().sum()
df
# Out:
#                                              job_titles  \
# 0                        full stack developer , student
# 1                                     software engineer
# 2                                                No Job
# 3     work from home , support analyst , software an...
# 4                           work from home , classifier
# ...                                                 ...
# 1568  branch manager , embedded software developer ,...
# 1569      devops , senior android developer , team lead
# 1570  devops engineer , traffic manager , release ma...
# 1571                                         classifier
# 1572                                             No Job
#
#                                                  skills  work_experience  \
# 0     algorithms , interview , visualisation , robot...                0
# 1     core java , algorithms , sql tools , deep lear...                0
# 2     digital signal processing , algorithms , capac...                0
# 3     big data analytics , award , training , comput...                1
# 4     functionality , algorithms , spark , data visu...                0
# ...                                                 ...              ...
# 1568  digital communication , api , atom , robot , c...                2
# 1569  reporting , functionality , socket.io , mockit...                2
# 1570  version control , renewals , nfs , telugu , vi...               12
# 1571  natural language , matplotlib , boost , custom...                0
# 1572  employability , python , github , javascript ,...                0
#
#      bachelor_degrees master_degrees docterte_degrees           profiles
# 0               BTECH             MS              PHD             Github
# 1                  BE     MS , MTECH        No Degree         No Profile
# 2          BTECH , BS             MS        No Degree           Linkedin
# 3             BE , BS             MS        No Degree         No Profile
# 4          BTECH , BS             MS        No Degree             Github
# ...               ...            ...              ...                ...
# 1568               BE     MS , MTECH        No Degree  Github , Linkedin
# 1569               BS             MS        No Degree         No Profile
# 1570          BS , BS  MSC , MS , MS        No Degree         No Profile
# 1571        No Degree             MS        No Degree         No Profile
# 1572               BS      No Degree        No Degree             Github
#
# [1573 rows x 7 columns]

# %% [markdown]
# ## Defining the functions to calculate the rank of the resume

# %%
lemmatizer = WordNetLemmatizer()
analyzer = CountVectorizer().build_analyzer()

def stemmed_words(doc):
    return (lemmatizer.lemmatize(w,get_wordnet_pos(w)) for w in analyzer(doc) if w not in set(stp.words('english')))

# %%
def get_wordnet_pos(word):
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ,
                "N": wordnet.NOUN,
                "V": wordnet.VERB,
                "R": wordnet.ADV}
    return tag_dict.get(tag, wordnet.NOUN)

# %%
def get_tf_idf_cosine_similarity(job_desc,all_resumes):
    tf_idf_vect = TfidfVectorizer(analyzer=stemmed_words)
    tf_idf_desc_vector = tf_idf_vect.fit_transform([job_desc]).todense()
    tf_idf_resume_vector = tf_idf_vect.transform(all_resumes).todense()
    cosine_similarity_list = []
    for i in range(len(tf_idf_resume_vector)):
        cosine_similarity_list.append(cosine_similarity(tf_idf_desc_vector,tf_idf_resume_vector[i])[0][0])
    return cosine_similarity_list

# %% [markdown]
# ## Opening the Job Description from the text file

# %%
with open('/content/drive/MyDrive/Shubham/CsvFiles/Job Description.txt','r',encoding = 'utf-8') as f:
  file_desc_lst =  [r.replace('\n', '') for r in f.readlines()]
